# %%
import opstrat as op

# %%
from alpaca.trading.client import TradingClient

API_KEY = "PKZN00J3U31FC13BVNN8"
SECRET_KEY = "I0Va6E7EJwZ5NF8nJcJEeLzRJ4WHseSpbjJVvXyt"

trading_client = TradingClient(API_KEY, SECRET_KEY, paper=True)

# %%
from paperbroker.paperbroker import PaperBroker
from paperbroker.paperbroker.orders import Order

# %%
broker = PaperBroker()

# %%
account = broker.open_account()
account.cash = 100000

# %%
quote = broker.get_quote('GOOG')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [77], in <cell line: 1>()
# ----> 1 quote = broker.get_quote('GOOG')
#
# File ~\PycharmProjects\EE399\paperbroker\paperbroker\PaperBroker.py:40, in PaperBroker.get_quote(self, asset)
#      39 def get_quote(self, asset):
# ---> 40     return self.quote_adapter.get_quote(asset)
#
# File ~\PycharmProjects\EE399\paperbroker\paperbroker\adapters\quotes\GoogleFinanceQuoteAdapter.py:36, in GoogleFinanceQuoteAdapter.get_quote(self, asset)
#      32     return matches[0]
#      34 else:
# ---> 36     google_quotes = getQuotes(asset.symbol)
#      38     if google_quotes is None or len(google_quotes) == 0:
#      39         raise Exception("GoogleFinanceAdapter.get_quote: No quote found for {}".format(asset.symbol))
#
# File ~\anaconda3\lib\site-packages\googlefinance\__init__.py:70, in getQuotes(symbols)
# ...

# %%
import cv2

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
img = cv2.imread('img_1.png')

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
faces=face_cascade.detectMultiScale(img, 1.1, 4)

# %%
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

# %%
cv2.imshow('img', img)
cv2.waitKey()
# Out:
# -1
